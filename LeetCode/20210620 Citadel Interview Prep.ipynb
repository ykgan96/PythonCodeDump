# %%
import numpy as np
import pandas as pd

# %%
def isPrime(n):
    for i in range(2,int(n**0.5)+1):
        if n%i==0:
            return False
    return True

# %%
for k in range(1,10+1):
    print(k, isPrime(k))
# Out:
# 1 True
# 2 True
# 3 True
# 4 False
# 5 True
# 6 False
# 7 True
# 8 False
# 9 False
# 10 False

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]

# %%
[*zip(*matrix)]
# Out:
# [(1, 4, 7), (2, 5, 8), (3, 6, 9)]
