# %%
s='abghdab234234vnsakdgnfas'
try:
    i = s.index('g')
except:
    i=-1
i
# Out:
# -1

# %%
def IsSubsequence(s,t):
    i = -1
    for item in s:
        try:
            i = t.index(item)
            t = t[i+1:]
        except:
            return False
    return True

# %%
IsSubsequence("axc","ahbgdc")
# Out:
# False

# %%
IsSubsequence("abc","ahbgdc")
# Out:
# True
