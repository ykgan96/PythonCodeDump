# %% [markdown]
# # Binary Search

# %%
def bs(obj,nums):
    l, r = 0, len(nums)-1
    while l<r:
        m = (l+r)//2
        if nums[m]==obj:
            return m
        elif nums[m]>obj:
            r = m-1
        else:
            l = m+1
    if nums[l]==obj:
        return l
    else:
        return -1

# %%
bs(2,[0,1,3])
# Out:
# -1

# %%
def FindLowest(nums):
    #nums: rotated sorted array
    l,r = 0, len(nums)-1
    while l<r:
        m = (l+r)//2
        if nums[m]>nums[r]:
            l = m+1
        else:
            r = m
    return l

# %%
FindLowest([5,6,7,0,1,2,3,4])
# Out:
# 3
