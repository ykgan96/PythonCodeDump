# %%
def floodFill(image, sr, sc, newColor):
    """
    :type image: List[List[int]]
    :type sr: int
    :type sc: int
    :type newColor: int
    :rtype: List[List[int]]
    """
    m,n = len(image), len(image[0])
    if m==0 or n==0: return image
    x = [[0,1],[0,-1],[1,0],[-1,0]]
    def dfs(image,icur,jcur,From,To):
        if icur not in range(m) or jcur not in range(n) or image[icur][jcur]==To:
            return
        image[icur][jcur]=To
        for opt in x:
            if (icur+opt[0]) in range(m) and (jcur+opt[1]) in range(n) and image[icur+opt[0]][jcur+opt[1]]==From:
                dfs(image,icur+opt[0],jcur+opt[1],From,To)

    dfs(image,sr,sc,image[sr][sc],newColor)

    return image

# %%
image = [[0,0,0],[0,1,1]]

# %%
floodFill(image,1,1,1)
# Out:
# [[0, 0, 0], [0, 1, 1]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution(object):
    def sufficientSubset(self, root, limit):
        """
        :type root: TreeNode
        :type limit: int
        :rtype: TreeNode
        """
        if not root: return root
        if not root.left and not root.right:
            return None if root.val<limit else root
        
        root.left = self.sufficientSubset(root.left,limit-root.val)
        root.right = self.sufficientSubset(root.right,limit-root.val)
        if not root.left and not root.right:
            root = self.sufficientSubset(root,limit)
        
        return root
